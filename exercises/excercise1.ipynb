# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sklearn as sk

# %%
path = '/Users/amalkadri/Documents/CodeBook/ECO395M/'
path_abia = 'data/ABIA.csv'
path_olympics = 'data/olympics_top20.csv'
path_sclass = 'data/sclass.csv'

abia = pd.read_csv(path+path_abia).fillna(0)
olympics = pd.read_csv(path+path_olympics)
sclass = pd.read_csv(path+path_sclass)
abia['UniqueCarrier'][abia['UniqueCarrier']=='9E']
# Out:
# 0        9E
# 3        9E
# 134      9E
# 170      9E
# 258      9E
#          ..
# 99155    9E
# 99167    9E
# 99191    9E
# 99217    9E
# 99256    9E
# Name: UniqueCarrier, Length: 2549, dtype: object

# %%
# plt.boxplot(abia["UniqueCarrier"][abia['UniqueCarrier']=='9E'],abia["CarrierDelay"][abia['UniqueCarrier']=='9E'])
carriers = abia["UniqueCarrier"].unique().tolist()

flightdata = pd.DataFrame()
for carrier in carriers:
    flightdata[carrier] = abia["CarrierDelay"][(abia['UniqueCarrier']==carrier) & (abia['CarrierDelay']>0)].reset_index(drop=True)

flightdata

fig = plt.figure(figsize =(10, 7))
ax = fig.add_axes([0, 0, 1, 1])
ax.set_xticklabels(carriers)


plt.boxplot(flightdata)
plt.show()
# Out:
# /var/folders/cp/g93dz2hs5lq68hdb_5gtgbd40000gn/T/ipykernel_67189/591115182.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(carriers)
